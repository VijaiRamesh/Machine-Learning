# %%
#Importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading csv file using pandas.read_csv and saved in data variable
data = pd.read_csv("insurance_pre.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#independent variable is an input(age,bmi,children)
independent = data[["age","bmi","children","sex_male","smoker_yes"]]
#Depedent variable is output(charges)
dependent = data[["charges"]]

# %%
#Creating a model for train set
#from sklearn library call model_selection function and import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent,dependent, test_size = 1/3, random_state = 0)

# %%
#Standardization is changing every colume into same range of value
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {"criterion":["mae","mse","friedman_mse"],
             "splitter":["best", "random"],"max_features":["auto","sqrt","log2"]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose = 3,n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# C:\Users\vijai\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    8.4s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=-1,
#              param_grid={'criterion': ['mae', 'mse', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter{'criterion': 'mse', 'max_features': 'auto', 'splitter': 'random'}: 0.6678406797174989

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.036460      0.007367         0.000000        0.000000
# 1        0.031254      0.000001         0.000000        0.000000
# 2        0.020837      0.007366         0.010419        0.007367
# 3        0.031251      0.000006         0.000000        0.000000
# 4        0.026046      0.007366         0.005209        0.007366
# 5        0.015626      0.000004         0.005208        0.007366
# 6        0.015626      0.000005         0.005211        0.007369
# 7        0.015624      0.000005         0.005211        0.007369
# 8        0.010417      0.007366         0.005208        0.007366
# 9        0.010421      0.007369         0.005211        0.007369
# 10       0.005211      0.007369         0.015626        0.000006
# 11       0.015626      0.000004         0.000000        0.000000
# 12       0.010415      0.007365         0.005211        0.007369
# 13       0.005211      0.007369         0.005211        0.007370
# 14       0.018418      0.003952         0.008035        0.006532
# 15       0.010415      0.007365         0.005208        0.007366
# 16       0.005211      0.007369         0.005211        0.007369
# 17       0.010420      0.007368         0.005207        0.007363
#
#    param_criterion param_max_features param_splitter  \
# 0              mae               auto           best
# 1              mae               auto         random
# 2              mae               sqrt           best
# 3              mae               sqrt         random
# 4              mae               log2           best
# 5              mae               log2         random
# 6              mse               auto           best
# 7              mse               auto         random
# 8              mse               sqrt           best
# 9              mse               sqrt         random
# 10             mse               log2           best
# 11             mse               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mae', 'max_features': 'auto', '...           0.651288
# 1   {'criterion': 'mae', 'max_features': 'auto', '...           0.541153
# 2   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.562256
# 3   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.420568
# 4   {'criterion': 'mae', 'max_features': 'log2', '...           0.448562
# 5   {'criterion': 'mae', 'max_features': 'log2', '...           0.629996
# 6   {'criterion': 'mse', 'max_features': 'auto', '...           0.545137
# 7   {'criterion': 'mse', 'max_features': 'auto', '...           0.670006
# 8   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.643493
# 9   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.598749
# 10  {'criterion': 'mse', 'max_features': 'log2', '...           0.546187
# 11  {'criterion': 'mse', 'max_features': 'log2', '...           0.558488
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.543519
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.599383
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.541534
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.514781
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.580143
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.532077
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.634400           0.676886         0.654188        0.017457
# 1            0.662841           0.710873         0.638180        0.071464
# 2            0.616022           0.677224         0.618437        0.046979
# 3            0.677630           0.574708         0.557482        0.105678
# 4            0.650811           0.632401         0.577114        0.091362
# 5            0.550111           0.651659         0.610611        0.043649
# 6            0.681558           0.696441         0.640938        0.068126
# 7            0.699948           0.653910         0.674616        0.019066
# 8            0.731571           0.627028         0.667337        0.045877
# 9            0.548206           0.618645         0.588545        0.029635
# 10           0.366306           0.668673         0.527077        0.124112
# 11           0.502762           0.585341         0.548875        0.034375
# 12           0.669476           0.690997         0.634562        0.065080
# 13           0.672977           0.669624         0.647274        0.033949
# 14           0.474126           0.728772         0.581433        0.107675
# 15           0.653266           0.658308         0.608680        0.066540
# 16           0.351256           0.566086         0.499253        0.104719
# 17           0.615584           0.590401         0.579301        0.034991
#
#     rank_test_score
# 0                 3
# 1                 6
# 2                 8
# 3                15
# 4                14
# 5                 9
# 6                 5
# 7                 1
# 8                 2
# 9                11
# 10               17
# 11               16
# 12                7
# 13                4
# 14               12
# 15               10
# 16               18
# 17               13

# %%
age_input,bmi_input,childern_input,sex_male,smoker_yes=int(input("Enter the Age: ")),int(input("Enter the BMI: ")),int(input("Enter the Children: ")),int(input("Enter the Sex Male 0 or Female 1: ")),int(input("Enter Smoker YES 0 or NO 1: "))
# Out:
# Enter the Age: 24
# Enter the BMI: 34
# Enter the Children: 3
# Enter the Sex Male 0 or Female 1: 0
# Enter Smoker YES 0 or NO 1: 1

# %%
#Calculating prediction value
Future_Prediction=regressor.predict([[age_input,bmi_input,childern_input,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[48549.17835]
